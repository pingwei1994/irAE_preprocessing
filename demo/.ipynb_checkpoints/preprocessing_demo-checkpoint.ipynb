# %%
import pandas as pd
import extract_mentions as eim
import drug_ici_config
import json

# import importlib
# importlib.reload(eim)
# Out:
# JSON file created successfully.

# %%
config_file_json = "drug_symptom_dicts.json"
def load_config(config_file_json):
    with open(config_file_json, 'r') as f:
        config = json.load(f)
    return config
config = load_config(config_file_json)

# %%
notes = pd.read_csv('/users/PAS2015/pingwei821/model1/consolidated_pipeline/datasets/co_learning_round1/notes_cancer_info.csv')

# %%
notes
# Out:
#       report_id                                              notes  \
# 0     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 1     569534356  note_date [**2016-01-30**]\n_sent_ Chief Compl...
# 2     636814063  note_date [**2016-07-23**]\n_sent_ Chief Compl...
# 3     643765670  note_date [**2016-08-20**]\n_sent_ Chief Compl...
# 4     582392387  note_date [**2016-02-27**]\n_sent_ Patient see...
# ...         ...                                                ...
# 1357  679422336  note_date [**2017-01-04**]\n_sent_ Brief Rheum...
# 1358  669720528  note_date [**2016-11-28**]\n_sent_ [**Known pa...
# 1359  671179057  note_date [**2016-12-06**]\n_sent_ [**Telephon...
# 1360  678895276  note_date [**2017-01-05**]\n_sent_ [**Telephon...
# 1361  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
#
#      patient_index min_note_date max_note_date  number_of_notes  \
# 0        patient 1        1/2/16      10/15/16               11
# ...

# %%
drug_mentions = eim.extract_ici_mentions(notes, config['drug_dict'])
symptom_mentions = eim.extract_symptom_mentions(notes, config['symptom_dict'])
# Out:
# 100%|██████████| 1362/1362 [00:02<00:00, 545.56it/s]

# %%
drug_mentions
# Out:
#       report_id                                              notes  \
# 0     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 1     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 2     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 3     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 4     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# ...         ...                                                ...
# 7807  678895276  note_date [**2017-01-05**]\n_sent_ [**Telephon...
# 7808  678895276  note_date [**2017-01-05**]\n_sent_ [**Telephon...
# 7809  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 7810  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 7811  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
#
#       standard_drug matched_variant  start_index  variant_length  \
# 0         nivolumab       NIVOLUMAB         2331               9
# ...

# %%
symptom_mentions
# Out:
#        report_id                                              notes  \
# 0      559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 1      559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 2      559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 3      559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 4      559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# ...          ...                                                ...
# 26549  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 26550  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 26551  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 26552  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 26553  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
#
#           standard_symptom      matched_variant  start_index  variant_length  \
# ...

# %%
drug_mentions.columns
# Out:
# Index(['report_id', 'notes', 'standard_drug', 'matched_variant', 'start_index',
#        'variant_length', 'max_length_variant', 'theword', 'drug_adjacent'],
#       dtype='object')

# %%
symptom_mentions[['report_id', 'standard_symptom', 'matched_variant',
       'start_index', 'variant_length', 'theword',
       'symptom_adjacent']].to_csv('symptom_mentions.csv', index=False)
drug_mentions[['report_id', 'standard_drug', 'matched_variant', 'start_index',
       'variant_length', 'theword', 'drug_adjacent']].to_csv('drug_mentions.csv', index=False)

# %%
drug_part = drug_mentions.groupby(['report_id', 'notes', 'standard_drug'], as_index=False).agg({'drug_adjacent':list})
symptom_part = symptom_mentions.groupby(['report_id', 'notes', 'standard_symptom'], as_index=False).agg({'symptom_adjacent':list})

# %%
symptom_part = symptom_mentions.groupby(['report_id', 'notes', 'standard_symptom'], as_index=False).agg({'symptom_adjacent':list})

# %%
symptom_part
# Out:
#        report_id                                              notes  \
# 0       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 1       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 2       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 3       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 4       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# ...          ...                                                ...
# 12255  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 12256  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 12257  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 12258  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 12259  867146080  906125600 6/28/18 867146080 chief complaint pa...
#
#           standard_symptom                                   symptom_adjacent
# ...

# %%
final_data = drug_part.merge(symptom_part, on=['report_id', 'notes'], how='left')

# %%
final_data = final_data.merge(notes[['report_id','patient_index']], on = 'report_id', how='left')

# %%
final_data
# Out:
#        report_id                                              notes  \
# 0       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 1       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 2       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 3       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# 4       41119568  note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...
# ...          ...                                                ...
# 16286  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 16287  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 16288  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 16289  867146080  906125600 6/28/18 867146080 chief complaint pa...
# 16290  867146080  906125600 6/28/18 867146080 chief complaint pa...
#
#       standard_drug                                      drug_adjacent  \
# 0        ipilimumab  [note_date [**2011-11-10**]\n_sent_ LINIC NOTE...
# ...

# %%
patient_split = pd.read_csv('/users/PAS2015/pingwei821/model1/consolidated_pipeline/datasets/co_learning_round1/patients_split_with_info.csv')
patient_note_date = pd.read_csv('/users/PAS2015/pingwei821/model1/consolidated_pipeline/datasets/co_learning_round1/patient_note_date_map.csv')

# %%
patient_split.head(5)
# Out:
#    subject_id min_note_date max_note_date  number_of_notes  \
# 0   900027850    2016-06-09    2016-07-01                4
# 1   900060862    2015-01-15    2015-05-08               13
# 2   900068150    2016-09-08    2017-09-03               24
# 3   900069135    2016-09-24    2017-09-04               23
# 4   900075450    2017-02-04    2017-04-21               28
#
#                                      ICD-O Site Code  \
# 0                                     C66.9 - Ureter
# 1  C44.3 - Skin of other and unspecified parts of...
# 2                           C34.3 - Lung, lower lobe
# 3                           C34.1 - Lung, upper lobe
# 4                           C34.3 - Lung, lower lobe
#
#                         ICD-O Histology Code  \
# 0  8120/3 - Transitional cell carcinoma, NOS
# 1  8742/3 - Lentigo maligna melanoma (C44._)
# 2      8070/3 - Squamous cell carcinoma, NOS
# 3  8046/3 - Non-small cell carcinoma (C34._)
# 4               8140/3 - Adenocarcinoma, NOS
#
# ...

# %%
train_val_test_split = patient_note_date[['subject_id', 'report_id', 'patient_index']].merge(patient_split[['subject_id', 'split']], on='subject_id', how='left')

# %%
train_val_test_split.to_csv('train_val_test_split.csv', index=False)

# %%
train_val_test_split
# Out:
#       subject_id  report_id patient_index     split
# 0      900301310  559201815     patient 1   testing
# 1      900301310  569534356     patient 1   testing
# 2      900301310  636814063     patient 1   testing
# 3      900301310  643765670     patient 1   testing
# 4      900301310  582392387     patient 1   testing
# ...          ...        ...           ...       ...
# 1357   900109845  679422336    patient 46  training
# 1358   900109845  669720528    patient 46  training
# 1359   900109845  671179057    patient 46  training
# 1360   900109845  678895276    patient 46  training
# 1361   900109845  670652042    patient 46  training
#
# [1362 rows x 4 columns]

# %%
final_data = final_data.merge(train_val_test_split[['report_id', 'patient_index', 'split']], on=['report_id', 'patient_index'], how='left')

# %%
final_data.to_csv('final_data.csv', index=False)

# %% [markdown]
# # Appendix

# %%
import ast

    # Function to convert string representation of list to list
def convert_to_list(s):
    return ast.literal_eval(s)

train_pool = pd.read_csv('/users/PAS2015/pingwei821/model1/consolidated_pipeline/datasets/train_df_with_smoothed_cluster.csv', converters = {'trimmed_partition': convert_to_list, 'trimmed_label':convert_to_list})[['report_id', 'standard_drug', 'ade_check', 'ade_loc0', 'ade_loc1']]
test_pool = pd.read_csv('/users/PAS2015/pingwei821/model1/consolidated_pipeline/datasets/test_df_with_smoothed_cluster.csv', converters = {'trimmed_partition': convert_to_list, 'trimmed_label':convert_to_list})[['report_id', 'standard_drug', 'ade_check', 'ade_loc0', 'ade_loc1']]
pool = pd.concat([train_pool, test_pool]).drop_duplicates(subset=['report_id', 'standard_drug', 'ade_check', 'ade_loc0', 'ade_loc1']).reset_index(drop=True)

notes = pd.read_csv('/users/PAS2015/pingwei821/model1/consolidated_pipeline/datasets/co_learning_round1/notes_cancer_info.csv')
pool = pool.merge(notes[['report_id', 'notes','ICD-O Site Code', 'ICD-O Histology Code']], on='report_id', how='left')

# %%
pool.columns
# Out:
# Index(['report_id', 'standard_drug', 'ade_check', 'ade_loc0', 'ade_loc1',
#        'notes', 'ICD-O Site Code', 'ICD-O Histology Code'],
#       dtype='object')

# %%
pool.drop_duplicates(subset = ['report_id', 'ade_check', 'ade_loc0', 'ade_loc1'])
# Out:
#        report_id standard_drug      ade_check  ade_loc0  ade_loc1  \
# 0       41119568    ipilimumab      Arthritis      2645      2654
# 1       41119568    ipilimumab         Goiter      2670      2676
# 2       41119568    ipilimumab   Hypertension      2428      2440
# 3       41119568    ipilimumab    Hypothyroid     10512     10523
# 4       41119568    ipilimumab    Hypothyroid      2655      2666
# ...          ...           ...            ...       ...       ...
# 25224  861279861     nivolumab     joint pain      9892      9902
# 25225  861279861     nivolumab    pneumonitis      2352      2363
# 25226  861279861     nivolumab  poor appetite      1286      1299
# 25227  861279861     nivolumab            sob      1622      1625
# 25228  861279861     nivolumab            sob      2734      2737
#
#                                                    notes      ICD-O Site Code  \
# 0      note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...      C69.3 - Choroid
# ...

# %%
symptom_dict = {
    "Arthritis": ['Arthritis', 'arthritis', 'arthiritis'],
    "Goiter": ['Goiter', 'goiter'],
    "Hypertension": ['Hypertension', 'hypertension', 'HTN', 'htn', 'HYPERTENSION'],
    "Hypothyroid": ['Hypothyroid', 'hypothyroid', 'hypothyroidism'],
    "Rash": ['Rash', 'rash'],
    "Edema": ['edema', 'Edema', 'Swelling', 'swelling'],
    "Erythema": ['erythema', 'Erythema', 'Redness', 'redness', 'erythematous'],
    "Increased TSH": ['increased TSH', 'Elevated TSH'],
    "Pruritus": ['prurit', 'Prurit', 'pruritis', 'pruritus','itch', 'itching', 'itchy'],
    "Abdominal Pain": ['abdominal pain', 'Abdominal pain', 'abd pain', 'abdominal cramp'],
    "Diarrhea": ['diarrhea', 'Diarrhea', 'diarhea', 'loose stool', 'Loose stool', 'watery stool', 'frequent stool', 'Frequent stool', 'Frequent BM\'s', 'frequent bowel movement'],
    "Shortness of Breath": ['short of breath', 'shortness of breath', 'Shortness of breath','Shortness of Breath','Shortness', 'shortness', 'SOB', 'sob', 'dyspneic with exertion', 'dyspnea with exertion', 'Dyspnea on exertion', 'dyspnea on exertion'],
    "Dyspnea": ['dyspnea', 'Dyspnea', 'dypsnea'],
    "Arthralgia": ['Arthralgia', 'arthralgia', 'joint pain', 'Joint pain', 'Joint Pain', 'joint ache', 'joint swelling', 'athralgias'],
    "Cough": ['Cough', 'cough'],
    "Dermatitis": ['Dermatitis', 'dermatitis'],
    "Dry Skin": ['Dry skin', 'skin dryness'],
    "Fatigue": ['Fatigue', 'fatigue', 'FATIGUE'],
    "Myalgia": ['Myalgia', 'myalgia', 'muscle pain', 'Muscle pain'],
    "Muscle Weakness": ['Muscle weakness', 'muscle weakness', 'Muscle Weakness'],
    "Stiffness": ['stiffness', 'Stiffness'],
    "Back Pain": ['back pain', 'Back pain', 'Back Pain'],
    "Osteoarthritis": ['osteoarthritis'],
    "Adrenal Insufficiency": ['Adrenal insufficiency', 'adrenal insufficiency'],
    "Low TSH": ['low TSH'],
    "RA": ['ra'],
    "DOE": ['DOE', 'doe'],
    "Diabetes": ['DIABETES', 'Diabetes', 'diabetes'],
    "Allergy": ['allergy', 'allergies'],
    "Rheumatoid": ['rheumatoid'],
    "Pneumonitis": ['pneumonitis', 'Pneumonitis', 'pnuemonitis'],
    "Pneumonia":["pneumonia"],
    "Appetite Decrease": ['appetite is decreasing', 'appetite has been low', 'decreased appetite', 'poor appetite', 'appetite is decreased', 'appetite has decreased', 'appetite: poor', 'appetite poor', 'lack of appetite', 'low appetite', 'loss of appetite'],
    "Numbness": ['numbness'],
    "Transaminitis": ['transaminitis', 'Transaminitis'],
    "Dizziness": ['Dizziness', 'dizziness', 'dizzy', 'lightheaded', 'Lightheaded'],
    "Chest Pain": ['Chest pain', 'chest pain', 'pleuritic chest pain', 'pain in upper chest'],
    "Syncope": [ 'Syncope', 'syncope', 'Near syncope', 'near syncopal episode', 'near-syncopal episode', 'syncopal episode', 'syncopal episodes', 'syncopal events', 'lost consciousness'],
    "Fibrosis": ['fibrosis', 'Fibrosis'],
    "Tachycardia": ['tachycardia', 'Tachycardia'],
    "Afib": ['Afib', 'afib', 'AFIB'],
    "MI": ['MI'],
    "Increased Oxygen Demand": ['Increased oxygen demands', 'increased oxygen'],
    "Hepatitis": ['hepatitis', 'Hepatitis', 'HEPATITIS', 'hepatis'],
    "Hyperthyroid": ['Hyperthyroid', 'hyperthyroid'],
    "Blood in Stool": ['blood in stool', 'blood in his stool', 'BRBPR', 'bloody stool', 'Hematochezia', 'hematochezia', 'dark stool'],
    "Rheumatology": ['RHEUMATOLOGY', 'Rheumatology', 'rheumatology'],
    "Colitis": ['colitis', 'Colitis', 'colities', 'colities,'],
    "Thromboembolism": ['Thromboembolism', 'VTE'],
    "Arrhythmia": ['arrhythmia'],
    "CPK Elevation": ['ymptomatic elevation in CPK', 'symptomatic elevation in CPK (341)'],
    "Muscle Tenderness": ['muscle tenderness'],
    "Muscle Cramps": ['muscle cramps'],
    "Abnormal LFTs": ['Abnormal LFTs', 'abnormal LFTs', 'LFT abnormalities', 'LFT derangement', 'elevated liver enzyme', 'Elevated liver enzyme', 'Elevated LFTs', 'elevated LFTs', 'elevated lft', 'lfts', 'increased lft\'s', "increase lft's", "increased lft'", "elevation of the lft's", 'lfts continue to improve'],
    "Hepatotoxicity": ['hepatotoxicity', 'inflammatory component of liver injury'],
    "Encephalopathy": ['encephalopathy'],
    "Thyroiditis": ['thyroiditis'],
    "T4 Low": ['t4 low'],
    "Bowel Movements": ['bowel movements'],
    "ICH": ['ich'],
    "Coagulopathy":['Coagulopathy', 'coagulopathy'],
}

# 1️⃣ 构建 variant → standard 的反向映射字典
variant_to_standard = {
    variant: standard
    for standard, variants in symptom_dict.items()
    for variant in variants
}

# 2️⃣ 假设 df["symptom_variant"] 是你的列，进行映射：
pool["symptom_standard"] = pool["ade_check"].map(variant_to_standard)

all_values = []

for i in symptom_dict.keys():
    all_values = all_values + symptom_dict[i]

# %%
pool
# Out:
#        report_id  standard_drug      ade_check  ade_loc0  ade_loc1  \
# 0       41119568     ipilimumab      Arthritis      2645      2654
# 1       41119568     ipilimumab         Goiter      2670      2676
# 2       41119568     ipilimumab   Hypertension      2428      2440
# 3       41119568     ipilimumab    Hypothyroid     10512     10523
# 4       41119568     ipilimumab    Hypothyroid      2655      2666
# ...          ...            ...            ...       ...       ...
# 25245  861279861  pembrolizumab     joint pain      9892      9902
# 25246  861279861  pembrolizumab    pneumonitis      2352      2363
# 25247  861279861  pembrolizumab  poor appetite      1286      1299
# 25248  861279861  pembrolizumab            sob      1622      1625
# 25249  861279861  pembrolizumab            sob      2734      2737
#
#                                                    notes      ICD-O Site Code  \
# 0      note_date [**2011-11-10**]\n_sent_ LINIC NOTE ...      C69.3 - Choroid
# ...

# %%
drug_mentions = eim.extract_ici_mentions(notes)

# %%
drug_mentions
# Out:
#       report_id                                              notes  \
# 0     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 1     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 2     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 3     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# 4     559201815  note_date [**2016-01-02**]\n_sent_ Chief Compl...
# ...         ...                                                ...
# 7810  678895276  note_date [**2017-01-05**]\n_sent_ [**Telephon...
# 7811  678895276  note_date [**2017-01-05**]\n_sent_ [**Telephon...
# 7812  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 7813  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
# 7814  670652042  note_date [**2016-12-03**]\n_sent_ CHIEF COMPL...
#
#       standard_drug matched_variant  start_index  variant_length  \
# 0         nivolumab       NIVOLUMAB         2331               9
# ...

# %%
drug_mentions['drug_adjacent'].iloc[0]
# Out:
# 'agnostic surgical biopsy on [**2015-06-21**], which was determined to be most consistent with MDM2-amplified (by FISH) inflammatory-type retroperitoneal liposarcoma.\n_sent_ She completed 2 cycles of neoadjuvant doxorubicin/DTIC; unfortunately, her restaging CT on [**2015-08-29**] was consistent with interval progression.\n_sent_ Interval History [**Known patient lastname 1**] [**Initials (NamePattern4) **] [**Known patient firstname 2**] is seen with her husband today for tox check prior to c2D2 <drug> nivolumab </drug>.\n_sent_ She underwent exploratory laparotomy on [**2015-10-09**].\n_sent_ Intra-operative assessment was notable for sarcomatosis.\n_sent_ Since she was treated for c.diff colitis, her nausea and diarrhea have resolved and her appetite has returned.\n_sent_ Her activity level is much better and fatigue is decreased.\n_sent_ She is tolerating the nivolumab well.\n_sent_ She rates her pain as a [**01-27**] today, located mostly in her abdomen and back.\n_sent_ She us
# ...
